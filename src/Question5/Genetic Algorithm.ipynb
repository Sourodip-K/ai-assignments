# %%
# random string using Genetic Algorithm
import random

# %%
# Number of individuals in each generation
POPULATION_SIZE = 100
# Valid genes
GENES = '''abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOP
QRSTUVWXYZ 1234567890, .-;:_!"#%&/()=?@${[]}'''
# Target string to be generated
TARGET = "Sourodip Kundu"

# %%
class Individual(object):
    '''
    Class representing individual in population
    '''
    def __init__(self, chromosome):
        self.chromosome = chromosome
        self.fitness = self.cal_fitness()
    
    @classmethod
    def mutated_genes(self):
        '''
        create random genes for mutation
        '''
        global GENES
        gene = random.choice(GENES)
        return gene
 
    @classmethod
    def create_gnome(self):
        '''
        create chromosome or string of genes
        '''
        global TARGET
        gnome_len = len(TARGET)
        return [self.mutated_genes() for _ in range(gnome_len)]
 
    def mate(self, par2):
        '''
        Perform mating and produce new offspring
        '''
        # chromosome for offspring
        child_chromosome = []
        for gp1, gp2 in zip(self.chromosome, par2.chromosome):   
            # random probability 
            prob = random.random()
            # if prob is less than 0.45, insert gene
            # from parent 1
            if prob < 0.45:
                child_chromosome.append(gp1)
            # if prob is between 0.45 and 0.90, insert
            # gene from parent 2
            elif prob < 0.90:
                child_chromosome.append(gp2)
            # otherwise insert random gene(mutate),
            # for maintaining diversity
            else:
                child_chromosome.append(self.mutated_genes())
        # create new Individual(offspring) using
        # generated chromosome for offspring
        return Individual(child_chromosome)
 
    def cal_fitness(self):
        '''
        Calculate fittness score, it is the number of
        characters in string which differ from target
        string.
        '''
        global TARGET
        fitness = 0
        for gs, gt in zip(self.chromosome, TARGET):
            if gs != gt: 
                fitness+= 1
        return fitness

# %%
# Driver code
def main():
    global POPULATION_SIZE
    #current generation
    generation = 1
    found = False
    population = []
    # create initial population
    for _ in range(POPULATION_SIZE):
        gnome = Individual.create_gnome()
        population.append(Individual(gnome))
    while not found:
        # sort the population in increasing order of fitness score
        population = sorted(population, key = lambda x:x.fitness)
        # if the individual having lowest fitness score ie.
        # 0 then we know that we have reached to the target
        # and break the loop
        if population[0].fitness <= 0:
            found = True
            break
        # Otherwise generate new offsprings for new generation
        new_generation = []
        # Perform Elitism, that mean 10% of fittest population
        # goes to the next generation
        s = int((10*POPULATION_SIZE)/100)
        new_generation.extend(population[:s])
        # From 50% of fittest population, Individuals
        # will mate to produce offspring
        s = int((90*POPULATION_SIZE)/100)
        for _ in range(s):
            parent1 = random.choice(population[:50])
            parent2 = random.choice(population[:50])
            child = parent1.mate(parent2)
            new_generation.append(child)
        population = new_generation
        print("Generation: {}\tString: {}\tFitness: {}".\
              format(generation,
              "".join(population[0].chromosome),
              population[0].fitness))
        generation += 1
    print("Generation: {}\tString: {}\tFitness: {}".\
          format(generation,
          "".join(population[0].chromosome),
          population[0].fitness))
if __name__ == '__main__':
    main()
# Out:
# Generation: 1	String: m1oE]e]w ZhK2[	Fitness: 13
# Generation: 2	String: S
# ;rbL8Z{g pwQ	Fitness: 12
# Generation: 3	String: @0uro!jXsDYLVy	Fitness: 11
# Generation: 4	String: @0uro!jXsDYLVy	Fitness: 11
# Generation: 5	String: @0uro!jXsDYLVy	Fitness: 11
# Generation: 6	String: n9urAW}w 8ujZU	Fitness: 10
# Generation: 7	String: SHmEobiw KgjWy	Fitness: 9
# Generation: 8	String: SSzrovGX KuL?R	Fitness: 8
# Generation: 9	String: SHuqobie KMnZy	Fitness: 7
# Generation: 10	String: SHuqobie KMnZy	Fitness: 7
# Generation: 11	String: SYuroLiC K n=$	Fitness: 6
# Generation: 12	String: SYuroLiC K n=$	Fitness: 6
# Generation: 13	String: S5uroOiX KunwB	Fitness: 5
# Generation: 14	String: S5uroOiX KunwB	Fitness: 5
# Generation: 15	String: S5uroOiX KunwB	Fitness: 5
# Generation: 16	String: S5uro3iX KundB	Fitness: 4
# Generation: 17	String: S5uro3iX KundB	Fitness: 4
# Generation: 18	String: S5uro3iX KundB	Fitness: 4
# Generation: 19	String: S5uro3iX KundB	Fitness: 4
# Generation: 20	String: S5uro3iX KundB	Fitness: 4
# Generation: 21	String: S5uro3iX KundB	Fitness: 4
# Generation: 22	String: SouroLiC Kund/	Fitness: 3
# Generation: 23	String: SouroLiC Kund/	Fitness: 3
# Generation: 24	String: SouroLiC Kund/	Fitness: 3
# Generation: 25	String: SouroLiC Kund/	Fitness: 3
# Generation: 26	String: SouroLiC Kund/	Fitness: 3
# Generation: 27	String: SouroLiC Kund/	Fitness: 3
# Generation: 28	String: SouroLiC Kund/	Fitness: 3
# Generation: 29	String: SouroLiC Kund/	Fitness: 3
# Generation: 30	String: SouroLiC Kund/	Fitness: 3
# Generation: 31	String: SouroLiC Kund/	Fitness: 3
# Generation: 32	String: SouroLiC Kund/	Fitness: 3
# Generation: 33	String: SouroLiC Kund/	Fitness: 3
# Generation: 34	String: Souro&iC Kundu	Fitness: 2
# Generation: 35	String: Souro&iC Kundu	Fitness: 2
# Generation: 36	String: Souro&iC Kundu	Fitness: 2
# Generation: 37	String: Souro&iC Kundu	Fitness: 2
# Generation: 38	String: Souro&iC Kundu	Fitness: 2
# Generation: 39	String: Souro&iC Kundu	Fitness: 2
# Generation: 40	String: Souro&iC Kundu	Fitness: 2
# Generation: 41	String: Souro&iC Kundu	Fitness: 2
# Generation: 42	String: Souro&iC Kundu	Fitness: 2
# Generation: 43	String: Souro&iC Kundu	Fitness: 2
# Generation: 44	String: Souro&iC Kundu	Fitness: 2
# Generation: 45	String: Souro&iC Kundu	Fitness: 2
# Generation: 46	String: Souro&iC Kundu	Fitness: 2
# Generation: 47	String: Souro&iC Kundu	Fitness: 2
# Generation: 48	String: Souro&iC Kundu	Fitness: 2
# Generation: 49	String: SourodiC Kundu	Fitness: 1
# Generation: 50	String: SourodiC Kundu	Fitness: 1
# Generation: 51	String: SourodiC Kundu	Fitness: 1
# Generation: 52	String: SourodiC Kundu	Fitness: 1
# Generation: 53	String: SourodiC Kundu	Fitness: 1
# Generation: 54	String: SourodiC Kundu	Fitness: 1
# Generation: 55	String: SourodiC Kundu	Fitness: 1
# Generation: 56	String: SourodiC Kundu	Fitness: 1
# Generation: 57	String: SourodiC Kundu	Fitness: 1
# Generation: 58	String: SourodiC Kundu	Fitness: 1
# Generation: 59	String: SourodiC Kundu	Fitness: 1
# Generation: 60	String: SourodiC Kundu	Fitness: 1
# Generation: 61	String: SourodiC Kundu	Fitness: 1
# Generation: 62	String: SourodiC Kundu	Fitness: 1
# Generation: 63	String: SourodiC Kundu	Fitness: 1
# Generation: 64	String: SourodiC Kundu	Fitness: 1
# Generation: 65	String: SourodiC Kundu	Fitness: 1
# Generation: 66	String: SourodiC Kundu	Fitness: 1
# Generation: 67	String: SourodiC Kundu	Fitness: 1
# Generation: 68	String: SourodiC Kundu	Fitness: 1
# Generation: 69	String: SourodiC Kundu	Fitness: 1
# Generation: 70	String: SourodiC Kundu	Fitness: 1
# Generation: 71	String: SourodiC Kundu	Fitness: 1
# Generation: 72	String: SourodiC Kundu	Fitness: 1
# Generation: 73	String: SourodiC Kundu	Fitness: 1
# Generation: 74	String: SourodiC Kundu	Fitness: 1
# Generation: 75	String: SourodiC Kundu	Fitness: 1
# Generation: 76	String: SourodiC Kundu	Fitness: 1
# Generation: 77	String: SourodiC Kundu	Fitness: 1
# Generation: 78	String: SourodiC Kundu	Fitness: 1
# Generation: 79	String: SourodiC Kundu	Fitness: 1
# Generation: 80	String: SourodiC Kundu	Fitness: 1
# Generation: 81	String: SourodiC Kundu	Fitness: 1
# Generation: 82	String: SourodiC Kundu	Fitness: 1
# Generation: 83	String: SourodiC Kundu	Fitness: 1
# Generation: 84	String: SourodiC Kundu	Fitness: 1
# Generation: 85	String: SourodiC Kundu	Fitness: 1
# Generation: 86	String: SourodiC Kundu	Fitness: 1
# Generation: 87	String: SourodiC Kundu	Fitness: 1
# Generation: 88	String: SourodiC Kundu	Fitness: 1
# Generation: 89	String: SourodiC Kundu	Fitness: 1
# Generation: 90	String: SourodiC Kundu	Fitness: 1
# Generation: 91	String: SourodiC Kundu	Fitness: 1
# Generation: 92	String: SourodiC Kundu	Fitness: 1
# Generation: 93	String: SourodiC Kundu	Fitness: 1
# Generation: 94	String: SourodiC Kundu	Fitness: 1
# Generation: 95	String: SourodiC Kundu	Fitness: 1
# Generation: 96	String: SourodiC Kundu	Fitness: 1
# Generation: 97	String: SourodiC Kundu	Fitness: 1
# Generation: 98	String: SourodiC Kundu	Fitness: 1
# Generation: 99	String: SourodiC Kundu	Fitness: 1
# Generation: 100	String: Sourodip Kundu	Fitness: 0
